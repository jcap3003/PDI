# %%
import cv2
from sklearn.cluster import KMeans

# %%
img = cv2.imread('../imgs/naruto.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img_feat = img.reshape(-1,3)
km = KMeans(n_clusters = 7)
c = km.fit_predict(img_feat)
import numpy as np
for x in range(img.shape[0]):
    for y in range(img.shape[1]):
        img[x,y] = km.cluster_centers_[c[img.shape[1]*x+y]]
        if x%1000 == 0 and y%1000 == 0:
            print("{} {}".format(x,y))
plt.figure(figsize = (10,10))
plt.imshow(img)
# Out:
# /home/aluno-d03/.local/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return_n_iter=True)
# 0 0
# 0 1000

# %%
# Out:
# 0 0
# 0 1000
